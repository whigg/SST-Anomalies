# %%
import sstOceanColor
import os
import netCDF4
import datetime
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
from importlib import reload

# %%
reload(sstOceanColor)
# Out:
# <module 'sstOceanColor' from '/home/ctroupin/Projects/Atlantic-Anomalies/sstOceanColor.py'>

# %%
Wind = sstOceanColor.windfield()

# %%
windir = "/home/ctroupin/Data/ECMWF/"
windfile = "wind_1deg_month.nc"
# windfile = "wind_0125deg_2010.nc"

# %%
Wind.readfile(os.path.join(windir, windfile))

# %%
Wind.extractime(2016, 2)

# %%
#mg = Basemap(projection='ortho', lon_0=-15, lat_0=20, resolution='c')

# %%
#Wind.plot_global(mg, scale=600)
#plt.show()

# %%
domain = (-55., 0., 25., 65.)

# %%
Wind.extractdomain(domain)

# %%
plt.figure(figsize=(10, 10))
llon2, llat2 = np.meshgrid(Wind.lonregion, Wind.latregion)
qv = plt.quiver(llon2, llat2, Wind.uregion, Wind.vregion, Wind.speedregion)
plt.colorbar(qv)
plt.show()
plt.close()

# %%
fig = plt.figure(figsize=(10, 10))
plt.streamplot(Wind.lonregion, Wind.latregion, Wind.uregion, Wind.vregion, 
                      linewidth=2, cmap='autumn', density=3)
plt.pcolormesh(Wind.lonregion, Wind.latregion, Wind.speedregion, alpha=.2)
plt.xlim(domain[0], domain[1])
plt.show()
plt.close()

# %% [markdown]
# ### Wind.lonregion
